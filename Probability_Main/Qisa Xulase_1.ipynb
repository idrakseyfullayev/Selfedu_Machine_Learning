# %% [markdown]
# #### ✅ **1. UYUŞAN və UYUŞMAYAN HADİSƏLƏR**
#
# ##### **🔹 Uyuşan (kəsişən) hadisələr**
#
# >**Tərif:**: **Eyni anda baş verə bilən hadisələrdir. Yəni iki hadisənin kəsişməsi boş deyil.**
#
# **Sadə nümunə:**
# - A – “Kart seçəndə qırmızı gəlsin”
# - B – “Kart seçəndə onun üzərindəki rəqəm tək olsun”.
#
# Hər ikisi eyni anda mümkündür (məsələn: “qırmızı 5”).
# - Ona görə **A və B uyuşan hadisələrdir**.
#
# ---
#
# #### **🔹 Uyuşmayan (kəsişməyən) hadisələr**
#
# >**Tərif:**: **Eyni anda baş verə bilməyən hadisələr. Kəsişməsi boş çoxluqdur.**
#
# **Sadə nümunə:**
# - A – “Zəri atanda 2 düşsün”
# - B – “Zəri atanda 5 düşsün”.
#
# Bir atmada həm 2, həm 5 düşə bilməz.
# - Ona görə **A və B uyuşmayan hadisələrdir**.
#
# ---
#
# #### ✅ **2. ASILI və MÜSTƏQİL HADİSƏLƏR**
#
# ##### **🔹 Müstəqil hadisələr**
#
# >**Tərif:**: **Bir hadisənin baş verməsi digərinə təsir etmir.**
#
# **Sadə nümunə:**
# - A – “Pul atanda yazı düşsün”
# - B – “Zəri atanda 6 düşsün”.
#
# Pul atma zərin nəticəsinə təsir etmir.
# - Ona görə **A və B müstəqil hadisələrdir**.
#
# ---
#
# ##### **🔹 Asılı hadisələr**
#
# >**Tərif:**: **Bir hadisənin baş verməsi digərinin ehtimalını dəyişdirir.**
#
# **Sadə nümunə:**
# Bir torbada 3 qırmızı, 2 mavi top var.
#
# - A – “Qırmızı top çıxarmaq”
# - B – “Sonra yenə qırmızı top çıxarmaq (geri qoymadan)”
#
# Birinci alınan top ikinci ehtimala təsir edir (say dəyişir).
# - Ona görə **A və B asılı hadisələrdir**.
