# %% [markdown]
# #### 🔑 Əsas fikir
#
# **Uyuşan / uyuşmayan** başqa şeydir,
# **asılı / müstəqil** başqa şeydir.
#
# Biri digərini **məcbur etmir**.
#
# ---
#
# #### 1️⃣ Mümkün kombinasiyalar
#
# ##### ✔️ 1. **Uyuşan + asılı**
#
# ➡️ **OLA BİLƏR**
#
# Misal (sənin verdiyin):
#
# * A: cüt ədəd
# * B: 3-dən böyük ədəd
#   → kəsişmə var
#   → ehtimal dəyişir
#   ✅ uyuşan + asılı
#
# ---
#
# ##### ✔️ 2. **Uyuşan + müstəqil**
#
# ➡️ **OLA BİLƏR**
#
# Misal:
#
# * A: kart qırmızıdır
# * B: kart ürəkdir
#
# Ürək qırmızıdır, kəsişmə var,
# amma:
# $$
# P(B\mid A)=P(B)
# $$
#
# ✅ uyuşan + müstəqil
#
# ---
#
# ##### ✔️ 3. **Uyuşmayan + asılı**
#
# ➡️ **OLA BİLƏR**
#
# Misal:
#
# * A: zərdə 2 gəlməsi
# * B: zərdə 4 gəlməsi
#
# Birinin olması o birini **0 edir**
# $$
# P(B\mid A)=0 \neq P(B)
# $$
#
# ✅ uyuşmayan + asılı
#
# ---
#
# ##### ❌ 4. **Uyuşmayan + müstəqil**
#
# ➡️ **OLA BİLMƏZ** ❌
#
# Çünki:
# $$
# P(B\mid A)=0
# $$
# amma müstəqil olsaydı:
# $$
# P(B\mid A)=P(B)>0
# $$
#
# Ziddiyyət yaranır.
#
# ---
#
# #### 2️⃣ Yadda saxlamaq üçün cədvəl
#
# | Uyuşma    | Asılılıq | Mümkündür? |
# | --------- | -------- | ---------- |
# | Uyuşan    | Asılı    | ✅          |
# | Uyuşan    | Müstəqil | ✅          |
# | Uyuşmayan | Asılı    | ✅          |
# | Uyuşmayan | Müstəqil | ❌          |
#
# ---
#
# #### 🧠 Qızıl cümlə (imtahan üçün)
#
# > **Uyuşma hadisələrin birlikdə baş verə bilməsi ilə, asılılıq isə bir hadisənin digərinin ehtimalını dəyişməsi ilə bağlıdır; bu anlayışlar qarışıq şəkildə mövcud ola bilər.**

# %% [markdown]
# #### Hər **ikisində hadisələr MÜSTƏQİLDİR**, amma
# - birində **TOPLANIR**,
# - birində **VURULUR**.
#
# ---
#
# #### 🔹 MİSAL 1 — **MÜSTƏQİL + TOPLANMA**
#
# **Təcrübə:** Zər **iki dəfə** atılır.
#
# * **A:** 1-ci atışda **2** gəlməsi
# * **B:** 2-ci atışda **5** gəlməsi
#
# 📌 Atışlar bir-birinə təsir etmir → **müstəqildir**.
#
# #### Sual:
#
# ##### **2 və ya 5 gəlsin** (yəni **A ∪ B**)
#
# #### Hesab:
#
# $$
# P(A)=\frac{1}{6}, \quad P(B)=\frac{1}{6}
# $$
#
# $$
# P(A \cup B)=P(A)+P(B)-P(A\cap B)
# $$
#
# $$
# P(A\cap B)=\frac{1}{6}\cdot\frac{1}{6}=\frac{1}{36}
# $$
#
# $$
# P(A \cup B)=\frac{1}{6}+\frac{1}{6}-\frac{1}{36}
# =\frac{11}{36}
# $$
#
# ✅ **Müstəqildir**
# ✅ **Toplama istifadə olundu**
#
# ---
#
# #### 🔹 MİSAL 2 — **MÜSTƏQİL + VURULMA**
#
# **Təcrübə:** Zər **iki dəfə** atılır.
#
# * **A:** 1-ci atışda **2** gəlməsi
# * **B:** 2-ci atışda **5** gəlməsi
#
# 📌 Yenə **müstəqildir**.
#
# #### Sual:
#
# #### **1-ci 2 VƏ 2-ci 5 gəlsin** (yəni **A ∩ B**)
#
# ### Hesab:
#
# $$
# P(A \cap B)=P(A)\cdot P(B)
# =\frac{1}{6}\cdot\frac{1}{6}
# =\frac{1}{36}
# $$
#
# ✅ **Müstəqildir**
# ✅ **Vurma istifadə olundu**
#
# ---
#
# #### 🔑 SON NƏTİCƏ (çox vacib)
#
# | Sualda nə var? | Əməliyyat |
# | -------------- | --------- |
# | **“VƏ YA”**    | Toplama   |
# | **“VƏ”**       | Vurma     |
#
# > **Müstəqillik əməliyyatı yox, ehtimalların bir-birinə təsir edib-etməməsini bildirir.**

# %% [markdown]
# ### Məsələ: İki dəfə zar atışı
#
# Tutaq ki, iki zar atılır. Biz 1 və ya 3 gəlmə ehtimalını soruşuruq.
#
# #### Addım 1: Hadisələrin mümkün nəticələri
#
# İki zarın bütün mümkün nəticələri (6 \times 6 = 36) dır.
#
# #### Addım 2: Uğurlu nəticələri tapmaq
#
# 1 və ya 3 gəlməsi üçün hər zar müstəqildir. Birinci və ikinci zar üçün ehtimallar:
#
# * $P(\text{1 və ya 3}) = P(1) + P(3) = \frac{1}{6} + \frac{1}{6} = \frac{2}{6} = \frac{1}{3}$
#
# İki zar müstəqildir, buna görə “hər iki zar üçün 1 və ya 3 gəlməsi” ehtimalı:
# $$
# P(\text{hər iki zar 1 və ya 3}) = \frac{1}{3} \times \frac{1}{3} = \frac{1}{9}
# $$
#
# Amma əgər sual belədirsə: "**iki atışdan ən az birində 1 və ya 3 gəlməsi ehtimalı**", onda istifadə edirik:
#
# $$
# P(\text{ən az birində 1 və ya 3}) = 1 - P(\text{heç biri 1 və ya 3 deyil})
# $$
#
# Heç biri 1 və ya 3 gəlməməsi ehtimalı:
# $$
# P(\text{zar 1 və ya 3 deyil}) = 1 - \frac{1}{3} = \frac{2}{3}
# $$
# İki zar üçün:
# $$
# P(\text{heç biri 1 və ya 3 deyil}) = \frac{2}{3} \times \frac{2}{3} = \frac{4}{9}
# $$
#
# Beləliklə:
# $$
# P(\text{ən az birində 1 və ya 3}) = 1 - \frac{4}{9} = \frac{5}{9}
# $$
#
# ✅ Cavab: **5/9**

# %% [markdown]
# ### Daha Əhatəli izah

# %% [markdown]
# #### 🔹 1. **MÜSTƏQİL — TOPLANMA**
#
# - **Məsələ şərti:**
# - Zər **iki dəfə** atılır.
# - **1-ci atışda 2 və ya 2-ci atışda 5** gəlməsi ehtimalını tapın.
#
# 📌 **Mətndən bilinir:**
#
# - * “iki dəfə atılır”
# - * atışlar bir-birinə təsir etmir
# -  → **müstəqildir**
# -  → “və ya” → **toplanma**
#
# ##### **Həlli:**
#
# $$
# P = \frac{1}{6} + \frac{1}{6} - \frac{1}{36}
# = \frac{11}{36}
# $$
#
# ---
#
# #### 🔹 2. **MÜSTƏQİL — VURULMA**
#
# - **Məsələ şərti:**
# - Zər **iki dəfə** atılır.
# - **1-ci atışda 2 və 2-ci atışda 5** gəlməsi ehtimalını tapın.
#
# 📌 **Mətndən bilinir:**
#
# - * müstəqil təcrübələr
# - * “və” var
# -   → **vurma**
#
# ##### **Həlli:**
#
# $$
# P = \frac{1}{6} \cdot \frac{1}{6}
# = \frac{1}{36}
# $$
#
# ---
#
# #### 🔹 3. **ASILI — VURULMA**
#
# - **Məsələ şərti:**
# - Qutuda **3 qırmızı, 2 ağ top** var.
# - Toplar **geri qoyulmadan** ardıcıl götürülür.
# - **1-ci və 2-ci topun qırmızı** olması ehtimalını tapın.
#
# 📌 **Mətndən bilinir:**
#
# - * “geri qoyulmadan”
# -   → 2-ci hadisə 1-cidən asılıdır
# -   → **asılı + vurma**
#
# ##### **Həlli:**
#
# $$
# P = \frac{3}{5} \cdot \frac{2}{4}
# = \frac{3}{10}
# $$
#
# #### ⚠️ **ƏLAVƏ QEYD — ASILI + TOPLANMA**
#
# - **Məsələ şərti (toplama üçün):**
# - Eyni qutudan ardıcıl top götürülür (geri qoyulmadan).
# - **1-ci top qırmızı **və ya** 2-ci top qırmızı** olması ehtimalını tapın.
#
# ##### **Həlli (Asılı + Toplama):**
#
# $$
# P = P(1\text{-ci qırmızı}) + P(2\text{-ci qırmızı}) - P(1\text{VƏ}2\text{qırmızı})
# $$
#
# $$
# P = \frac{3}{5} + \frac{3}{5}\cdot\frac{2}{4} - \frac{3}{5}\cdot\frac{2}{4}
# = \frac{3}{5}
# $$
#
# Yəni **asılı + toplama da mümkündür** və **hesablanır**.
#
# ---
#
# #### 🔹 4. **UYUŞMAYAN — TOPLANMA**
#
# - **Məsələ şərti:**
# - Zər **1 dəfə** atılır.
# - **2 və ya 5** gəlməsi ehtimalını tapın.
#
# 📌 **Mətndən bilinir:**
#
# - * bir atış
# - * eyni anda mümkün deyil
# -   → **uyuşmayan + toplama**
#
# ##### **Həlli:**
#
# $$
# P = \frac{1}{6} + \frac{1}{6}
# = \frac{1}{3}
# $$
#
# #### ❌ **ƏLAVƏ QEYD — UYUŞMAYAN + VURULMA**
#
# - **Uyuşmayan hadisələrdə VURULMA OLMAZ.**
#
# - Çünki:
#
# - * eyni anda baş verə bilmirlər
# - * kəsişmə **0**-dır
#
# - Yəni **“2 VƏ 5 gəlsin”** (1 atışda)
# - → **mümkün deyil**, ehtimal **0**.
#
# ---
#
# #### 🔹 5. **UYUŞAN — TOPLANMA**
#
# - **Məsələ şərti:**
# - Sinifdə **10 şagird** var.
# - Onlardan **3-ü qızdır**, **4-ü eynəklidir**,
# - **2-si həm qız, həm eynəklidir**.
# - Seçilən şagirdin **qız və ya eynəkli** olması ehtimalını tapın.
#
# 📌 **Mətndən bilinir:**
#
# - * eyni adam hər ikisinə düşə bilər
# -   → **uyuşan + toplama**
#
# ##### **Həlli:**
#
# $$
# P = \frac{3}{10} + \frac{4}{10} - \frac{2}{10}
# = \frac{5}{10} = \frac{1}{2}
# $$
#
# ---
#
# #### 🔹 6. **UYUŞAN — VURULMA**
#
# - **Məsələ şərti:**
# - Eyni sinifdən bir şagird seçilir.
# - Seçilən şagirdin **eynəkli qız** olması ehtimalını tapın.
#
# 📌 **Mətndən bilinir:**
#
# - * “eynəkli qız”
# -   → hadisələr üst-üstə düşür
# -   → **uyuşan + vurma**
#
# ##### **Həlli:**
#
# $$
# P = \frac{3}{10} \cdot \frac{2}{3}
# = \frac{1}{5}
# $$
#
# ---
#
# #### 🔑 **MƏTNƏ BAXIB BELƏ AYIRD EDƏCƏKSƏN**
#
# | Mətndə görünür         | Deməli    |
# | ---------------------- | --------- |
# | iki dəfə atılır        | müstəqil  |
# | geri qoyulmur          | asılı     |
# | və ya                  | toplama   |
# | və                     | vurma     |
# | eyni anda mümkün deyil | uyuşmayan |
# | eyni adam ola bilər    | uyuşan    |
#
# ---
#
# #### 🧠 **SON YADDAŞ CÜMLƏSİ (qızıl qayda)**
#
# - * **Asılı + toplama → OLUR**
# - * **Uyuşmayan + vurulma → OLMUR**
# - * **“VƏ YA” → toplama**
# - * **“VƏ” → vurma**

# %% [markdown]
# ### Permutasiya, Aranjman, Kombinezon

# %% [markdown]
# Əla, onda gəlin **bütün anlayışları bir yerdə, yekun şəkildə və addım-addım izah edək**, həm **təkrarlı**, həm **təkrarsız halları** göstərək.
#
# ---
#
# #### **1️⃣ Permutasiya**
#
# **Məna:**
#
# * Bütün elementlər götürülür və **sıra vacibdir**.
# * Təkrarlı və təkrarsız variantlar var.
#
# **Düsturlar:**
#
# * **Təkrarsız:** bütün elementlər fərqli olursa
#   $$
#   P_n = n!
#   $$
#
# * **Təkrarlı:** bəzi elementlər eyni olursa
#   $$
#   P = \frac{n!}{n_1! \cdot n_2! \cdot \dots}
#   $$
#   n₁, n₂ … eyni olan elementlərin sayı
#
# **Misal:**  A, B, C → hamısı  seçirik (mütləq şərtdir)
#
# **Misal:** A, B, C → təkrarsız permutasiya: ABC, ACB, BAC, BCA, CAB, CBA → 6 yol
#
# ---
#
# #### **2️⃣ Aranjman (Düzülüş)**
#
# **Məna:**
#
# * n elementdən **r ədədini seçirik**, sonra **ardıcıllıq vacibdir**.
# * Hamısını götürmürük, yalnız seçilmiş r element.
# * sonra Permutasiya kimi davam edir
#
# **Düsturlar:**
#
# * **Təkrarsız aranjman:**
#   $$
#   A_n^r = \frac{n!}{(n-r)!}
#   $$
#
# * **Təkrarlı aranjman:** (eyni element təkrar ola bilər)
#   $$
#   A = n^r
#   $$
#
# **Misal:** A, B, C, D → 3 seçirik
#
# * Təkrarsız: ABC, ACB, ABD, CBA … → 24 yol
# * Təkrarlı: AAA, AAB, … → 64 yol ((4^3))
#
# ---
#
# #### **3️⃣ Kombinasiya (Seçim)**
#
# **Məna:**
#
# * n elementdən **r ədədini seçirik**, **ardıcıllıq vacib deyil**.
# * Yalnız seçim vacibdir, sıra önəmli deyil.
# * ABC → CBA kimi təkrarlar olmaz.
#
# **Düsturlar:**
#
# * **Təkrarsız kombinasiya:**
#   $$
#   C_n^r = \frac{n!}{r!(n-r)!}
#   $$
#
# * **Təkrarlı kombinasiya:**
#   $$
#   C = C_{n+r-1}^r = \frac{(n+r-1)!}{r!(n-1)!}
#   $$
#
# **Misal:** A, B, C, D → 3 seçirik
#
# * Təkrarsız: ABC, ABD, ACD, BCD → 4 yol
# * Təkrarlı: AAA, AAB, ABB, … → 20 yol ((C_{4+3-1}^3 = C_6^3 = 20))
#
# ---
#
# #### **Qısa xülasə**
#
# 1. **Permutasiya** → hamısı götürülür, sıra vacibdir
# 2. **Aranjman** → seçilir, sıra vacibdir
# 3. **Kombinasiya** → seçilir, sıra vacib deyil
# 4. **Təkrarsız** → eyni element 1 dəfə
# 5. **Təkrarlı** → eyni element bir neçə dəfə gələ bilər
#
# ---
#
# Əgər istəyirsənsə, mən bunu **1 sadə nümunə ilə həm permutasiya, həm aranjman, həm kombinasiya, həm də təkrarlı-təkrarsız halları** yan-yana yazıb göstərim ki, **gözlə də görəsən və imtahanda qarışdırmayasan**.
#
# Bunu edim?
