# %% [markdown]
# ### Maksimum ehtimal metodu (Maximum Likelihood Estimation – MLE)

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Selfedu\Optimization Algorithms\Pictures\DSP_9_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 14):  # 1-dən 5-ə qədər
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 4:
        plt.figure(figsize=(8.8, 4))
    elif i == 7:
        plt.figure(figsize=(8.8, 4)) 
    elif i == 9:
        plt.figure(figsize=(8.8, 4))
    elif i == 11:
        plt.figure(figsize=(8.8, 4))
    elif i == 12:
        plt.figure(figsize=(8.8, 4))         
    else:     
        plt.figure(figsize=(25, 5))  # Şəkilin ölçüsü    
        
    if i < 3:
        plt.title("""Logistic Resgression - Maksimum Ehtimal metodu""", size='14')
    elif i < 4:
        plt.title("""Maksimum Ehtimal metodu - Lost Func - Least Square Method ilə""", size='14')        
    elif i < 5:
        plt.title("""""", size='14')
    elif i < 6:
        plt.title("""Maksimum Ehtimal metodu - Lost Func - Adi Residuals Method ilə""", size='14')
    elif i < 7:
        plt.title("""ω(θ | ȳ) - hesablanması""", size='14')
    elif i < 8:
        plt.title("""""", size='14')
    elif i < 9:
        plt.title("""Sadə Maksimum Ehtimal Metodunda θ tapılması - Ağ Gauss səsi (Noise)-in Ehtimal sıxlığı ilə""", size='10.5')
    elif i < 10:
        plt.title("""""", size='14')
    elif i < 11:
        plt.title("""θ parametri üçün əlavə məlumatlar məlum olarsa""", size='14')
    elif i < 12:
        plt.title("""""", size='14')
    elif i < 13:
        plt.title("""""", size='14')        
        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ### Maksimum ehtimal metodu Düsturlarının izahı (Bayes risk / orta risk)

# %% [markdown]
# #### 🔹 1-ci düstur: **Orta (ümumi) risk**
#
# #### 📌 Düstur
#
# $$
# \bar{R}(\varepsilon) = M\{R(\varepsilon)\}
# = \int\limits_{-\infty}^{\infty} \cdots \int
# R(\theta \ \hat\theta) \ \omega(\theta,\bar y) \ d\theta \ dy_1\ldots dy_n
# $$
#
# ---
#
# #### 🔎 Bu düstur nəyi ifadə edir?
#
# Bu düstur **qərar qaydasının (ε)** bütün mümkün:
#
# * **parametr dəyərlərinə (θ)**
# * **müşahidələrə (y₁,…,yₙ)**
#
# görə **orta riskini** hesablayır.
#
# Yəni:
#
# > *“Modelim orta hesabla nə qədər səhv edir?”*
#
# ---
#
# #### 🔤 Dəyişənlərin izahı
#
# | Simvol                      | İzah                                                                                  |
# | --------------------------- | ------------------------------------------------------------------------------------- |
# | $$\bar{R}(\varepsilon)$$      | **Orta (Bayes) risk**                                                                 |
# | $$M\{\cdot\}$$                 | Riyazi gözləmə                                                                        |
# | $$R(\theta,\hat\theta)$$      | **Loss (itki) funksiyası** – həqiqi θ ilə qiymətləndirmə $\hat\theta$ arasındakı səhv |
# | $$\theta$$                    | Naməlum parametr                                                                      |
# | $$\hat\theta$$                | Qiymətləndirilmiş parametr (estimator)                                                |
# | $$\bar y = (y_1,\ldots,y_n)$$ | Müşahidələr vektoru                                                                   |
# | $$\omega(\theta,\bar y)$$     | θ və y üçün **birgə ehtimal sıxlığı**                                                 |
# | $$d\theta \ dy_1\ldots dy_n$$   | Bütün mümkün θ və müşahidələr üzrə inteqrasiya                                        |
#
# ---
#
# #### 🔹 2-ci düstur: **Birgə paylanmanın parçalanması**
#
# #### 📌 Düstur
#
# $$
# \omega(\theta,\bar y) = \omega(\theta\mid \bar y)\cdot \omega(\bar y)
# $$
#
# ---
#
# #### 🔎 Mənası
#
# Bu **Bayes qaydasıdır**.
#
# Birgə ehtimal sıxlığı:
#
# * **Posterior** × **Müşahidənin paylanması**
#
# kimi yazılır.
#
# ---
#
# #### 🔤 Dəyişənlər
#
# | Simvol                      | İzah                                              |
# | --------------------------- | ------------------------------------------------- |
# | $$\omega(\theta\mid \bar y)$$ | Posterior paylanma (θ verilmiş müşahidələrə görə) |
# | $$\omega(\bar y)$$            | Müşahidələrin ehtimal sıxlığı                     |
# | $$\omega(\theta,\bar y)$$     | Birgə ehtimal sıxlığı                             |
#
# ---
#
# #### 🔹 3-cü düstur: **Orta riskin açılması**
#
# #### 📌 Düstur
#
# $$
# \bar{R}(\varepsilon)
# = \int \cdots \int
# R(\theta,\hat\theta) \
# \omega(\theta\mid \bar y) \
# \omega(\bar y) \
# d\theta \ dy_1\ldots dy_n
# $$
#
# ---
#
# #### 🔎 Mənası
#
# Burada sadəcə **2-ci düsturu 1-ci düsturun yerinə qoyuruq**.
#
# Bu göstərir ki:
#
# * Risk əvvəlcə **θ-ya görə**
# * sonra **müşahidələrə görə**
#
# ortalama alınır.
#
# ---
#
# #### 🔹 4-cü düstur: **Şərti (posterior) risk**
#
# #### 📌 Düstur
#
# $$
# R_a(\bar y)
# = \int_{-\infty}^{\infty}
# R(\theta,\hat\theta) \
# \omega(\theta\mid \bar y) \ d\theta
# $$
#
# ---
#
# #### 🔎 Mənası
#
# Bu düstur:
#
# > *“Müşahidələr sabitdirsə ($\bar y$ verilibsə), θ üzrə orta risk nə qədərdir?”*
#
# yəni **posterior risk**.
#
# ---
#
# #### 🔤 Dəyişənlər
#
# | Simvol                      | İzah                   |
# | --------------------------- | ---------------------- |
# | $$R_a(\bar y)$$               | Posterior (şərti) risk |
# | $$\omega(\theta\mid \bar y)$$ | Posterior paylanma     |
# | $$d\theta$$                   | θ üzrə inteqrasiya     |
#
# ---
#
# #### 🔹 5-ci düstur: **Minimallaşdırma şərti**
#
# #### 📌 Düstur
#
# $$
# R_a(\bar y)
# = \int R(\theta,\hat\theta) \ \omega(\theta\mid \bar y) \ d\theta \ \longrightarrow \ \min
# $$
#
# ---
#
# #### 🔎 Əsas fikir (ÇOX VACİB)
#
# Bu deyir ki:
#
# > **Ən yaxşı estimator $\hat\theta$**
# > **posterior riski minimum edən estimatordır**
#
# Yəni:
#
# * Kvadratik loss → **posterior orta**
# * Absolut loss → **posterior median**
# * 0–1 loss → **posterior maksimum (MAP)**
#
# çıxır.
#
# ---
#
# #### ✅ Qısa yekun
#
# 1. **1-ci düstur** – ümumi (Bayes) risk
# 2. **2-ci düstur** – Bayes qaydası
# 3. **3-cü düstur** – orta riskin açılması
# 4. **4-cü düstur** – posterior risk
# 5. **5-ci düstur** – optimal qərar şərti

# %% [markdown]
# ### Maksimum Ehtimal metodu - Lost Func - Least Square Method ilə

# %% [markdown]
# #### **Kvadrat itkisi funksiyası üçün Bayes estimatoru**
#
# #### 1️⃣ Risk funksiyası nədir?
#
# Kvadrat itkisi üçün Bayes riski belə tərif olunur:
#
# $$
# R_a(\bar y)
# = \int_{-\infty}^{\infty} (\theta-\hat\theta)^2 \ \omega(\theta\mid\bar y) \ d\theta
# $$
#
# **Məna:**
#
# * $(\theta-\hat\theta)^2$ → təxmin səhvinin cəzası
# * $\omega(\theta\mid\bar y)$ → posterior paylanma
# * İntegral → bütün mümkün $\theta$-lar üzrə **orta risk**
#
# Məqsədimiz: **$\hat\theta$-ni elə seçək ki, risk minimum olsun**.
#
# ---
#
# #### 2️⃣ Minimum üçün törəmə = 0
#
# Risk $\hat\theta$-dən asılıdır, ona görə:
#
# $$
# \frac{dR_a(\bar y)}{d\hat\theta} = 0
# $$
#
# Leibniz qaydasına görə törəməni inteqralın içinə sala bilərik:
#
# $$
# \frac{d}{d\hat\theta}(\theta-\hat\theta)^2
# = -2(\theta-\hat\theta)
# $$
#
# Beləliklə:
#
# $$
# \int_{-\infty}^{\infty} 2(\theta-\hat\theta),\omega(\theta\mid\bar y),d\theta = 0
# $$
#
# (−2 və ya 2 nəticəyə təsir etmədiyi üçün sadələşdirilir.)
#
# ---
#
# #### 3️⃣ İntegralı açırıq
#
# $$
# \int \theta \ \omega(\theta\mid\bar y) \ d\theta - \hat\theta \int \omega(\theta\mid\bar y) \ d\theta = 0
# $$
#
# Burada:
#
# * $\hat\theta$ **$\theta$-dən asılı deyil**, ona görə inteqraldan kənara çıxır.
#
# ---
#
# #### 4️⃣ Posterior-un əsas xassəsi
#
# Posterior ehtimal paylanmasıdır, yəni:
#
# $$
# \int_{-\infty}^{\infty} \omega(\theta\mid\bar y) \ d\theta = 1
# $$
#
# ---
#
# #### 5️⃣ Son nəticə
#
# $$
# \hat\theta
# = \int_{-\infty}^{\infty} \theta \ \omega(\theta\mid\bar y) \ d\theta
# $$
#
# ---
#
# #### ✅ Yekun nəticə
#
# > **Kvadrat itkisi funksiyası üçün Bayes estimatoru posterior paylanmanın gözlənilən dəyəridir.**
#
# Yəni:
#
# * kvadrat cəza → **orta dəyəri** optimal edir
# * buna görə **posterior mean** alınır
#
# ---
#
# #### 🧠 1 cümləlik intuitiv izah
#
# > **Kvadrat səhv böyük xətaları çox cəzalandırdığı üçün, ən təhlükəsiz seçim posterior-un ortalamasıdır.**

# %% [markdown]
# ### Maksimum Ehtimal metodu - Lost Func - Adi Residuals Method ilə

# %% [markdown]
# $$
# R_a(\bar y) = \int_{-\infty}^{\infty} -\delta(\theta-\hat\theta) \ \omega(\theta\mid\bar y) \ d\theta = -\omega(\hat\theta\mid\bar y)
# $$
#
# **Məna:**
#
# * $\delta(\theta-\hat\theta)$ → yalnız $\theta=\hat\theta$ nöqtəsində “aktivdir”
# * $\omega(\theta\mid\bar y)$ → posterior ehtimal sıxlığı
# * Mənfi işarə → maksimumlaşdırma məsələsini minimumlaşdırmaya çevirmək üçündür
#
# ---
#
#
#
# #### Sual
#
# $$
# \int -\delta(\theta-\hat\theta) \ \omega(\theta\mid\bar y) \ d\theta
# $$
#
# **“$-\delta(\theta-\hat\theta)$ hara getdi?”**
#
# ---
#
# #### Qısa cavab
#
# 👉 **Delta funksiyası “yox olmur” — o, inteqralı hesablatdırır.**
# - Hesablama bitəndən sonra onun işi qurtarır, ona görə nəticədə görünmür.
#
# ---
#
# #### Addım-addım məntiq
#
# #### 1️⃣ Mənfi işarə
#
# $-1$ sadəcə **sabitdir** → nəticədə **qalır**:
#
# $$
# = - \int \delta(\theta-\hat\theta) \ \omega(\theta\mid\bar y) \ d\theta
# $$
#
# ---
#
# #### 2️⃣ Delta funksiyasının rolu
#
# $$
# \delta(\theta-\hat\theta)
# $$
#
# - 👉 **filtr / seçici** kimidir
# - 👉 deyir: *“yalnız $\theta=\hat\theta$ nöqtəsinə bax”*
#
# Əsas qayda:
# $$
# \int \delta(\theta-a)f(\theta) \ d\theta = f(a)
# $$
#
# ---
#
# #### 3️⃣ Delta öz funksiyasını yerinə yetirir
#
# $$
#  \int - \delta(\theta-\hat\theta) \ \omega(\theta\mid\bar y) \ d\theta = - \omega(\hat\theta\mid\bar y)
# $$
#
# 👉 **delta artıq lazım deyil**, çünki seçmə əməliyyatı bitdi
#
# ---
#
# #### 🔍 Fiziki analojiya
#
# * Delta = **düymə**
# * Basırsan → yalnız bir nöqtə seçilir
# * Seçildikdən sonra → düymə artıq görünmür
#
# ---
#
# #### 1 cümləlik yekun
#
# > **$\delta(\theta-\hat\theta)$ yoxa çıxmır, sadəcə inteqral zamanı $\theta=\hat\theta$ nöqtəsini “seçib” funksiyanı orada qiymətləndirir.**

# %% [markdown]
# ### Niyə Kvadratik loss ilə zirvəni ala bilmirik, Delta funksiyası isə zirvə alınır(1)

# %% [markdown]
# #### 1️⃣ Quadratic (kvadratik) loss funksiyası
#
# Formala baxaq:
#
# $$
# R_a(\bar{y}) = \int_{-\infty}^{\infty} (\theta - \hat{\theta})^2 \ \omega(\theta \mid \bar{y}) \ d\theta
# $$
#
# * Burada $\omega(\theta \mid \bar{y})$ — posterior ehtimal sıxlıq funksiyasıdır.
# * $\hat{\theta}$ — qərar funksiyası (estimator).
#
# **İzah:** Kvadratik loss üçün risk minimal olacaq $\hat{\theta}$ **posterior paylanmanın ortalaması** ilə. Yəni, $ \hat{\theta} = \mathbb{E}[\theta \mid \bar{y}] $.
#
# * Zirvə **maksimum ehtimal (MAP) dəyəri** deyil, çünki $(\theta - \hat{\theta})^2$ funksiyası simmetrikdir və bütün ehtimalları nəzərə alır.
# * Zirvə (maksimum) yalnız **posterior sıxlıq funksiyasının ən böyük nöqtəsi**ni göstərir, amma kvadratik loss bütün paylanmanı “orta” kimi qiymətləndirir.
#
# 💡 Nəticə: Kvadratik lossda zirvəni ala bilmirik, əvəzinə **ortalama** götürülür.
#
# ---
#
# #### 2️⃣ Dirac delta ilə linear loss
#
# Formala baxaq:
#
# $$
# R_a(\bar{y}) = \int_{-\infty}^{\infty} -\delta(\theta - \hat{\theta}) \ \omega(\theta \mid \bar{y}) \ d\theta
# $$
#
# * Burada $\delta(\cdot)$ — Dirac delta funksiyası.
# * İnteqrala baxanda:
#
# $$
# \int_{-\infty}^{\infty} \delta(\theta - \hat{\theta}) \ \omega(\theta \mid \bar{y}) \ d\theta = \omega(\hat{\theta} \mid \bar{y})
# $$
#
# * Yəni, **risk minimal olmaq üçün $\hat{\theta}$ seçmək istəyirik ki, $\omega(\hat{\theta}\mid \bar{y})$ maksimum olsun**.
# * Bu halda **zirvə (maksimum posterior) alınır**.
#
# 💡 Nəticə: Delta funksiyası sadəcə bir nöqtəni “seçir”, ona görə zirvə alınır.
#
# ---
#
# #### 3️⃣ Normal paylanma istisnası
#
# * Əgər posterior $\omega(\theta \mid \bar{y})$ **normal paylanma**dırsa:
#
#   * Normal paylanmanın **ortalaması** = **maksimum nöqtəsi** (zirvəsi).
#   * Ona görə həm kvadratik loss, həm delta loss eyni dəyəri verir.
#
# * Amma qeyri-normal paylanmada:
#
#   * Kvadratik loss → ortalama
#   * Delta funksiyası → zirvə
#
# ---
#
# ### ✅ Xülasə
#
# | **Loss növü**       | **Seçdiyi $\hat{\theta}$**  | **Zirvəni alır?**           |
# | ---------------- | ----------------------- | ----------------------- |
# | **Quadratic**       | **Posterior ortalama**      | **Yox (ümumiyyətlə)**       |
# | **Delta**           | **MAP (posterior zirvəsi)** | **Bəli**                    |
# | **Normal posterior** | **Ort. = MAP**              | **Hər ikisi zirvəni verir** |

# %% [markdown]
# ### Niyə Kvadratik loss ilə zirvəni ala bilmirik, Delta funksiyası isə zirvə alınır(2)

# %% [markdown]
# #### 1️⃣ Zirvə nədir və niyə vacibdir?
#
# * **Zirvə** = ehtimal paylanmasının ən yüksək nöqtəsi.
#
#   * Məsələn, əgər posterior paylanma belədirsə:
#
# ```
#   *
#  * *
# *   *
# ```
#
# Zirvə `*`-in ən yuxarı nöqtəsi olacaq.
#
# * **Ortalama** isə paylanmanın “tarazlıq nöqtəsi”dir.
#
#   * Məsələn, ağırlıqların mərkəzini tapmaq kimi.
#
# - 💡 Zirvə = “ən çox ehtimal olunan nöqtə”,
# - 💡 Ortalama = “bütün paylanmanın balans nöqtəsi”.
#
# ---
#
# #### 2️⃣ Kvadratik loss funksiyası
#
# Formala:
#
# $$
# R_a(\bar{y}) = \int (\theta - \hat{\theta})^2 \ \omega(\theta \mid \bar{y}) \ d\theta
# $$
#
# * Burada $(\theta - \hat{\theta})^2)$ — məsafəni kvadrat götürür.
# * Risk minimal etmək üçün $\hat{\theta}$-ni seçirsən ki, **bütün paylanmanın ortasına yaxın olsun**, yəni **ortalama**.
#
# **Nəticə:**
#
# * Kvadratik loss **zirvəni almır**, çünki o sadəcə “ən böyük ehtimal nöqtəsinə baxmır”, bütün paylanmanı nəzərə alır.
# * Zirvə ilə ortalama fərqli ola bilər, əgər paylanma **simmetrik deyil**.
#
# ---
#
# #### 3️⃣ Delta funksiyası ilə (linear) loss
#
# Formala:
#
# $$
# R_a(\bar{y}) = \int -\delta(\theta - \hat{\theta}) \ \omega(\theta \mid \bar{y}) \ d\theta
# $$
#
# * Delta funksiyası “yalnız bir nöqtəni seçir”.
# * İnteqral sadəcə həmin nöqtədəki ehtimalı götürür:
#
# $$
# \int \delta(\theta - \hat{\theta}) \ \omega(\theta \mid \bar{y}) d\theta = \omega(\hat{\theta}\mid \bar{y})
# $$
#
# * Risk minimal etmək üçün $\hat{\theta}$-ni seçirik ki, $\omega(\hat{\theta}\mid \bar{y})$ **maksimum olsun**.
#
# **Nəticə:**
#
# * Burada zirvə birbaşa alınır, çünki delta funksiyası yalnız bir nöqtəyə baxır.
#
# ---
#
# #### 4️⃣ Niyə normal paylanmada hər ikisi zirvəni verir?
#
# * Normal paylanma **simmetrik**dir və ortalaması zirvəsi ilə eyni yerdədir.
# * Ona görə:
#
# ```
# Kvadratik loss → Ortalama = Zirvə
# Delta loss → Zirvə = Ortalama
# ```
#
# * Amma qeyri-simmetrik paylanmada:
#
# ```
# Kvadratik loss → Ortalama ≠ Zirvə
# Delta loss → Zirvə
# ```
#
# ---
#
# ### 5️⃣ Sadə misal
#
# Tutaq ki, posterior belədir (sadələşdirilmiş):
#
# ```
# Paylanma: *
#           **
#            ***
#              **
#               *
# ```
#
# * **Zirvə:** ən yüksək ulduz (**3 ulduz**) → MAP
#
# * **Ortalama:** bütün paylanmanın tarazlıq nöqtəsi → Kvadratik loss üçün $\hat{\theta}$
#
# * Zirvə və ortalama fərqli ola bilər, çünki paylanma **simmetrik deyil**.

# %% [markdown]
# ### Posterior

# %% [markdown]
# #### 1️⃣ Posterior nədir?
#
# **Posterior ehtimal** — Bayes nəzəriyyəsinə görə **mövcud məlumatlara əsaslanaraq parametrin ehtimal paylanmasıdır**.
#
# Riyazi formada:
#
# $$
# \omega(\theta \mid \bar{y}) = \frac{f(\bar{y} \mid \theta) \cdot \pi(\theta)}{\int f(\bar{y} \mid \theta) \cdot \pi(\theta) \  d\theta}
# $$
#
# * $\theta$ — bilinməyən parametr (məsələn, bir sikkənin baş gəlmə ehtimalı).
# * $\bar{y}$ — müşahidə etdiyimiz məlumatlar.
# * $f(\bar{y} \mid \theta)$ — likelihood, yəni **parametr $\theta$ verilsə, məlumatın ehtimalı**.
# * $\pi(\theta)$ — prior, yəni **$\theta$-nın əvvəlki ehtimal paylanması**.
# * $\omega(\theta \mid \bar{y})$ — posterior, yəni **məlumatı gördükdən sonra $\theta$-nin ehtimal paylanması**.
#
# 💡 Sadə dillə desək:
#
# > Posterior = “Məlumatımı gördükdən sonra, parametrin hansı dəyərləri daha çox ehtimal olunur” deyən paylanmadır.
#
# ---
#
# #### 2️⃣ Misal
#
# Sikkə atırsan, əvvəlcə **prior** deyirsən: sikkə ədalətlidir, $P(\text{baş}) = 0.5$.
#
# * Sonra **10 dəfə atırsan** və 7 dəfə baş gəlir $(\bar{y} = 7)$.
# * İndi **posterior** deyir: “İndi 7/10 baş gəldiyinə görə, sikkənin baş gəlmə ehtimalı 0.5 deyil, daha yüksək ola bilər — bəlkə 0.7?”
#
# Posterior paylanma sikkənin “baş ehtimalını” qiymətləndirir.

# %% [markdown]
# ### Sadə Maksimum Ehtimal Metodunda θ tapılması - Ağ Gauss səsi (Noise)-in Ehtimal sıxlığı ilə

# %% [markdown]
# #### $\omega(n_k) = \omega(y_k \mid \theta)$ niyə?

# %% [markdown]
# $$
# y_k = \theta + n_k, \quad k = 1, 2, \dots, n
# $$
#
# burada:
# - $y_k$ – **ölçülən qiymət** (müşahidə),
# - $\theta$ – **naməlum sabit siqnal** (orta qiymət, gözlənilən dəyər),
# - $n_k$ – **ağ Gauss səsi (noise)**, ortalaması 0 və varyansı $\sigma^2$ olan normal paylanma:
#   $ n_k \sim \mathcal{N}(0, \sigma^2) $.
#
# ---
#
# #### 1. Nə üçün $\omega(n_k) = \omega(y_k \mid \theta)$ ?
#
# Çünki $y_k = \theta + n_k$ olduğundan, $\theta$ verilmiş halda $y_k$ ilə $n_k$ arasında **tək bir fərq** var: yerdəyişmə.
#
# Daha dəqiq desək:
#
# $$
# n_k = y_k - \theta
# $$
#
# Ona görə də $n_k$-nin ehtimal sıxlığı ilə $\theta$ verilmiş halda $y_k$-nin şərti ehtimal sıxlığı **eyni funksiya**dir, çünki:
#
# \$$
# \omega(n_k) = \omega(y_k - \theta)
# $$
# və
# $$
# \omega(y_k \mid \theta) = \omega(y_k - \theta)
# $$
# çünki $y_k \mid \theta$ normal paylanır: orta qiymət $\theta$, varyans $\sigma^2$.
#
# ---
#
# #### 2. Nə üçün Gauss düsturu belədir?
#
# Gauss səs üçün:
#
# $$
# \omega(n_k) = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{n_k^2}{2\sigma^2}}
# $$
#
# $n_k = y_k - \theta$ olduğu üçün:
#
# $$
# \omega(y_k \mid \theta) = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(y_k - \theta)^2}{2\sigma^2}}
# $$
#
# Burada **məna**: hər bir $y_k$ ölçməsi $\theta$ ətrafında təsadüfi səbəbdən (Gauss səsindən) qaynaqlanan sapma ilə alınır.
#
# ---
#
# #### 3. Statistik qiymətləndirmədə rolu
#
# Bu düstur **likelihood funksiyası** kimi işləyir:
# Verilmiş $\theta$ üçün müşahidələrimiz $\{y_1, y_2, \dots, y_n\}$ nə qədər ehtimal olunandır?
#
# Bütün müşahidələr müstəqil olduğu üçün ümumi likelihood:
#
# $$
# L(\theta) = \prod_{k=1}^n \omega(y_k \mid \theta)
# $$
#
# Buradan **maksimum likelihood qiymətləndiricisi** (ML) tapılır:
# $$
# \hat{\theta}_{ML} = \frac{1}{n} \sum_{k=1}^n y_k
# $$
# yəni ortalaması.
#
# ---
#
# #### 4. Xülasə
#
# $$
# \omega(n_k) = \omega(y_k \mid \theta)
# $$
# ifadəsi texniki olaraq doğrudur, çünki $n_k$ və $(y_k \mid \theta)$ eyni paylanmaya malikdir:
# $$
# \mathcal{N}(0, \sigma^2) \quad \text{və} \quad \mathcal{N}(\theta, \sigma^2)
# $$
# olmasına baxmayaraq, ikinci halda orta $\theta$-dır, lakin **şərti paylanma** $y_k - \theta$ kimi ifadə olunduğundan orta 0-a çevrilir, ona görə eyni sıxlıq funksiyası alınır.

# %% [markdown]
# ### $ \prod $ işarəsi **vurma əməlinin qısa yazılışıdır** (ingiliscə "product" — hasil).

# %% [markdown]
# #### **Ümumi forma:**
#
# $$
# \prod_{i=a}^{b} x_i = x_a \times x_{a+1} \times \dots \times x_b
# $$
#
# Yəni, $ i $ indeksi $ a $-dan $ b $-yə qədər gedərkən bütün $ x_i $ ifadələrini bir-birinə vur.
#
# ---
#
# #### **Sizin nümunənizdə:**
#
# $$
# L(\theta) = \prod_{k=1}^{n} \omega(y_k \mid \theta)
# $$
#
# Bu o deməkdir:
#
# $$
# L(\theta) = \omega(y_1 \mid \theta) \times \omega(y_2 \mid \theta) \times \dots \times \omega(y_n \mid \theta)
# $$
#
# ---
#
# #### **Mənası statistikada:**
#
# > Hər bir $ y_k $ müstəqil ölçmə olduğu üçün, bütün $ n $ ölçmənin birgə ehtimalı (likelihood) **fərdi ehtimalların hasilinə** bərabərdir.
#
# ---
#
# #### **Sadə misal:**
# Əgər  $n = 3$ olarsa:
#
# $$
# \prod_{k=1}^{3} \omega(y_k \mid \theta) = \omega(y_1 \mid \theta) \cdot \omega(y_2 \mid \theta) \cdot \omega(y_3 \mid \theta)
# $$

# %% [markdown]
# #### $$ L(\theta) = \prod_{i=1}^n f(y_i \mid \theta) = \prod_{i=1}^n \frac{1}{\sigma \sqrt{2\pi}} \exp\Biggl\{ - \frac{1}{2\sigma^2} \sum_{i=1}^{n} (y_i - \theta)^2 \Biggr\}$$  Düsturunda niyə $$\frac{1}{2\sigma^2} \sum_{i=1}^{n} (y_i - \theta)^2 \ \longrightarrow \ \min$$ niyə minumum edirik?

# %% [markdown]
# Düstur belədir:
#
# $$
# L(\theta) = \prod_{i=1}^n f(y_i \mid \theta)
# = \prod_{i=1}^n
# \frac{1}{\sigma \sqrt{2\pi}}
# \exp\Biggl\{ - \frac{1}{2\sigma^2} \sum_{i=1}^{n} (y_i - \theta)^2 \Biggr\}
# $$
#
# Bu, normal paylanma üçün likelihood funksiyasıdır.
#
# ---
#
# #### 1️⃣ Məqsəd
#
# Məqsədimiz **θ parametrini tapmaqdır ki, likelihood L(θ) maksimal olsun**:
#
# $$
# \hat{\theta}{MLE} = \arg\max\theta L(\theta)
# $$
#
# ---
#
# #### 2️⃣ Log-likelihood
#
# Çox vaxt hesablamaları asanlaşdırmaq üçün log alırıq, çünki log monoton artırıcı funksiyadır (maksimizasiya eyni qalır):
#
# $$
# \ell(\theta) = \log L(\theta) = \sum_{i=1}^n \log \frac{1}{\sigma\sqrt{2\pi}} - \sum_{i=1}^n \frac{(y_i - \theta)^2}{2\sigma^2}
# $$
#
# İlk hissə $\sum \log \frac{1}{\sigma\sqrt{2\pi}}$ θ-dən asılı deyil, buna görə maksimum θ-ni tapmaq üçün onu gözardı edə bilərik.
#
# Beləliklə, θ-ni maximallaşdırmaq bərabərdir:
#
# $$
# \max_\theta \ell(\theta) \quad \Leftrightarrow \quad \min_\theta \sum_{i=1}^n (y_i - \theta)^2
# $$
#
# Yəni, **likelihood-i maksimum etmək eyni zamanda kare fərqlərin cəmini minimum etməkdir**.
#
# ---
#
# #### 3️⃣ Nəticə
#
# * Likelihood funksiyasını **maksimize** etmək istəyirik.
# * Log-likelihood götürdükdən sonra θ-yə aid olmayan sabitləri çıxarırıq.
# * Nəticədə, $ \sum_{i=1}^n (y_i - \theta)^2 / (2\sigma^2) $ ifadəsini **minimallaşdırmaq** kifayət edir.
#
# Bu ifadə θ ilə bağlı olan yeganə hissədir. Ona görə də sadəcə **min** istənilir.

# %% [markdown]
# ### $$\frac{1}{2\sigma^2} \sum_{i=1}^{n} (y_i - \theta)^2 \longrightarrow \min$$ budan $\theta$ -nı tapmaq

# %% [markdown]
# Verilən ifadə:
#
# $$
# \frac{1}{2\sigma^2} \sum_{i=1}^{n} (y_i - \theta)^2  \longrightarrow  \min
# $$
#
# burada **θ üzrə minimallaşdırma** edirik.
#
# ---
#
# #### 1️⃣ Sadələşdirmə
#
# $\frac{1}{2\sigma^2}$ **müsbət sabitdir**, minimallaşdırmaya təsir etmir. Ona görə ekvivalent olaraq bunu minimallaşdırırıq:
#
# $$
# \sum_{i=1}^{n} (y_i - \theta)^2
# $$
#
# ---
#
# #### 2️⃣ Törəməni tapırıq (θ-yə görə)
#
# $$
# \frac{d}{d\theta} \sum_{i=1}^{n} (y_i - \theta)^2 = \sum_{i=1}^{n} 2(\theta - y_i)
# $$
#
# ---
#
# #### 3️⃣ Sıfıra bərabərləyirik
#
# $$
# \sum_{i=1}^{n} 2(\theta - y_i) = 0
# $$
#
# 2-ni ixtisar edək:
#
# $$
# \sum_{i=1}^{n} (\theta - y_i) = 0
# $$
#
# ---
#
# #### 4️⃣ Açırıq
#
# $$
# n\theta - \sum_{i=1}^{n} y_i = 0
# $$
#
# $$
# \theta = \frac{1}{n} \sum_{i=1}^{n} y_i
# $$
#
# ---
#
# #### ✅ Nəticə
#
# $$
# \boxed{
# \hat{\theta} = \bar{y}
# }
# $$
#
# yəni **θ-nin minimallaşdıran qiyməti müşahidələrin ədədi ortasıdır**.
#
# ---
#
# #### 🔎 İntuitiv mənası
#
# Kvadrat itki funksiyasında (least squares):
#
# * **Orta (mean)** — kvadrat məsafələri minimum edir
# * Median → absolute loss üçün
# * Mode → 0–1 loss üçün

# %% [markdown]
# ### $\theta$ parametri üçün əlavə məlumatlar məlum olarsa:

# %% [markdown]
# #### 1️⃣ Prior paylanma (əvvəlcədən bilik)
#
# $$
# \omega(\theta)=\frac{1}{\sigma_0\sqrt{2\pi}}
# \exp\left(-\frac{(\theta-\theta_0)^2}{2\sigma_0^2}\right)
# $$
#
# #### İzah:
#
# Bu, **θ parametrinin prior ehtimal sıxlığıdır** (θ haqqında ölçmədən əvvəlki bilik).
#
# **Dəyişənlər:**
#
# * $\theta$ — axtardığımız naməlum parametr
# * $\theta_0$ — θ üçün **prior orta qiymət**
# * $\sigma_0^2$ — prior dispersiya (əvvəlki inamın qeyri-müəyyənliyi)
# * $\omega(\theta)$ — θ-nın prior ehtimal sıxlığı
# * Bu paylanma **Normal (Gaussian)** paylanmadır
#
# ---
#
# #### 2️⃣ Bayes düsturu (əsas prinsip)
#
# $$
# \omega(\theta \mid \bar{y})
# \propto
# \omega(\bar{y} \mid \theta)\cdot \omega(\theta)
# $$
#
# #### İzah:
#
# Bu **Bayes qaydasıdır** — ölçmələrdən sonra θ haqqında yeni bilik.
#
# **Dəyişənlər:**
#
# * $\bar{y} = (y_1, y_2, \dots, y_n)$ — müşahidələr
# * $\omega(\bar{y} \mid \theta)$ — **likelihood** (θ verilmişkən ölçmələrin ehtimalı)
# * $\omega(\theta \mid \bar{y})$ — **posterior** (son ehtimal)
#
# > Qeyd: Sağ tərəf normallaşdırıcı sabitə bölünür, amma **MAP üçün bu sabit lazım deyil**.
#
# ---
#
# #### 3️⃣ Posterior sıxlığın açıq forması
#
# $$
# \omega(\theta \mid \bar{y})
# \propto
# \exp\left(
# -\frac{1}{2\sigma^2}
# \sum_{i=1}^n (y_i-\theta)^2
# -\frac{1}{2\sigma_0^2}(\theta-\theta_0)^2
# \right)
# $$
#
# ### İzah:
#
# Bu düstur **likelihood × prior**-un nəticəsidir.
#
# **Dəyişənlər:**
#
# * $y_i$ — i-ci müşahidə
# * $n$ — müşahidələrin sayı
# * $\sigma^2$ — ölçmə səs-küyünün dispersiyası
# * $\sigma_0^2$ — prior dispersiyası
#
# Birinci termin → **data uyğunluğu**
# İkinci termin → **priora yaxınlıq cəzası**
#
# ---
#
# #### 4️⃣ MAP kriteriyası (maksimumlaşdırma)
#
# Eksponentdəki mənfi ifadəni **minimum etmək** kifayətdir:
#
# $$
# \frac{1}{2\sigma^2}
# \sum_{i=1}^n (y_i-\theta)^2
# +
# \frac{1}{2\sigma_0^2}
# (\theta-\theta_0)^2
# \longrightarrow
# \min
# $$
#
# ### İzah:
#
# Bu, **MAP qiymətləndirmə kriteriyasıdır**.
#
# * 1-ci termin → ölçmələrə uyğunluq
# * 2-ci termin → prior biliyə sadiqlik
# * MAP = **data + prior balansı**
#
# ---
#
# ## 5️⃣ Vacib məna (intuisiya)
#
# * $\sigma_0^2 \to \infty$ → prior zəif → **MLE alınır**
# * $\sigma_0^2$ kiçik → prior güclü → nəticə $\theta_0$-a yaxın olur
# * MAP = **regularized least squares**
#
# ---
#
# ## 6️⃣ Qısa yekun
#
# | **Hissə**          | **Mənası**              |
# | -------------- | ------------------- |
# | **Prior**          | **Əvvəlki bilik**       |
# | **Likelihood**     | **Ölçmələrin modeli**   |
# | **Posterior**      | **Yeni bilik**          |
# | **MAP**            | **Posterior maksimumu** |
# | **Kvadrat termin** | **Cəza (penalty)**      |
#
# ---
#
# #### 7️⃣ **Şəkildə olan davam (MAP üçün qapalı həll)**
#
# Posterioru minimallaşdırdıqda **MAP qiymətləndiricisi** belə alınır:
#
# $$
# \hat{\theta} =
# \frac{\sigma_s^2}{\sigma_s^2 + \sigma_0^2} \, \theta_0
# +
# \frac{\sigma_0^2}{\sigma_s^2 + \sigma_0^2} \, \hat{\theta}_{ML}
# $$
#
#
# ### Burada:
#
# * $\hat{\theta}$ — **MAP qiymətləndiricisi**
# * $\theta_0$ — prior orta qiymət
# * $\hat{\theta}_{ML}$ — maksimum ehtimal (MLE) qiymətləndiricisi
# * $\sigma_0^2$ — prior dispersiyası
# * $\sigma_s^2$ — **MLE qiymətləndiricisinin dispersiyası**
#
# və
#
# $$
# \sigma_s^2 = \frac{\sigma^2}{n}
# $$
#
# ---
#
# #### Xüsusi hallar (şəkildəki kimi):
#
# 1️⃣ Əgər
# $$
# \sigma_0^2 < \sigma_s^2
# $$
# → prior daha güclüdür → $\hat{\theta}$ **$\theta_0$-a yaxınlaşır**
#
# 2️⃣ Əgər
# $$
# \sigma_0^2 = \sigma_s^2
# $$
# onda
#
# $$
# \hat{\theta} =
# 0.5 \, \theta_0 + 0.5 \, \hat{\theta}_{ML}
# $$
#
#
# yəni **prior və data bərabər çəkilidir**.
#
# ---
#
# #### 🔑 Əsas fikir (şəkildəki oxların mənası)
#
# MAP qiymətləndiricisi:
#
# > **Prior orta qiymət ilə MLE-nin çəkili ortalamasıdır**
# > və çəkilər **dispersiyaların tərsi ilə** müəyyən olunur.

# %% [markdown]
# ### 1-ci düstur necə olub 3-cü düstura çevrilib.

# %% [markdown]
# #### Addım–addım çevrilmə
#
# #### 1️⃣ Başlanğıc: prior paylanma (1-ci düstur)
#
# $$
# \omega(\theta) =
# \frac{1}{\sigma_0\sqrt{2\pi}}
# \exp\left(
# -\frac{(\theta-\theta_0)^2}{2\sigma_0^2}
# \right)
# $$
#
# Bu **θ üçün Normal prior**dur.
#
# ---
#
# #### 2️⃣ Likelihood yazılır (ölçmələrin modeli)
#
# Fərz edilir ki:
#
# $$
# y_i = \theta + \varepsilon_i,
# \quad
# \varepsilon_i \sim \mathcal N(0,\sigma^2)
# $$
#
# Deməli hər müşahidə üçün:
#
# $$
# \omega(y_i \mid \theta) =
# \frac{1}{\sigma\sqrt{2\pi}}
# \exp\left(
# -\frac{(y_i-\theta)^2}{2\sigma^2}
# \right)
# $$
#
# ---
#
# #### 3️⃣ Bütün müşahidələrin birgə ehtimalı
#
# Ölçmələr **müstəqildir**, ona görə vurulur:
#
# $$
# \omega(\bar y \mid \theta)
# =
# \prod_{i=1}^n \omega(y_i \mid \theta)
# $$
#
#
# Yerinə qoyaq:
#
# $$
# \omega(\bar y \mid \theta)
# =
# \frac{1}{(\sigma\sqrt{2\pi})^n}
# \exp\left(
# -\frac{1}{2\sigma^2}
# \sum_{i=1}^n (y_i-\theta)^2
# \right)
# $$
#
# 📌 **Burada cəm hardan gəldi?**
# Çünki
# $$
# e^{-a_1}\cdot e^{-a_2}\cdots e^{-a_n}
# =
# e^{-(a_1+a_2+\cdots+a_n)}
# $$
#
#
# ---
#
# #### 4️⃣ Bayes düsturu tətbiq olunur
#
# $$
# \omega(\theta\mid\bar y)
# \propto
# \omega(\bar y\mid\theta)\cdot\omega(\theta)
# $$
#
# İndi **2 və 3-cü addımı vururuq**.
#
# ---
#
# #### 5️⃣ Likelihood × Prior
#
# Sabitləri bir yerə yığaq:
#
# $$
# \frac{1}{(\sigma\sqrt{2\pi})^n}
# \cdot
# \frac{1}{\sigma_0\sqrt{2\pi}}
# =
# \frac{1}{\sigma_0(\sigma\sqrt{2\pi})^n\sqrt{2\pi}}
# $$
#
#
# Eksponentləri vururuq:
#
# $$
# \exp\left(
# -\frac{1}{2\sigma^2}
# \sum_{i=1}^n (y_i-\theta)^2
# \right)
# \cdot
# \exp\left(
# -\frac{(\theta-\theta_0)^2}{2\sigma_0^2}
# \right)
# $$
#
# ⬇️
#
# $$
# \exp\left(
# -\frac{1}{2\sigma^2}
# \sum_{i=1}^n (y_i-\theta)^2
# -\frac{1}{2\sigma_0^2}
# (\theta-\theta_0)^2
# \right)
# $$
#
#
# ---
#
# #### 6️⃣ Alınan nəticə = 3-cü düstur ✅
#
# $$
# \boxed{
# \omega(\theta \mid \bar{y})
# =
# \frac{1}{\sigma_0(\sigma\sqrt{2\pi})^n}
# \exp\left(
# -\frac{1}{2\sigma^2}
# \sum_{i=1}^n (y_i-\theta)^2
# -\frac{1}{2\sigma_0^2}
# (\theta-\theta_0)^2
# \right)
# }
# $$
#
#
# ---
#
# #### Qısa məna ilə
#
# | **Addım** | **Nə baş verdi**                 |
# | ----- | ---------------------------- |
# | **1 → 2** | **Likelihood yazıldı**           |
# | **2 → 3** | **Müstəqil müşahidələr vuruldu** |
# | **3 → 4** | **Bayes qaydası**                |
# | **4 → 5** | **Eksponentlər birləşdirildi**   |
# | **5 → 6** | **Posterior alındı**             |
#
# ---
#
# #### Əsas fikir (yadda saxla)
#
# > **Normal prior × Normal likelihood = Normal posterior**

# %% [markdown]
# ### Prior və Posterior anlayışları

# %% [markdown]
# - > Qısa cavab: **MLE-də prior və posterior YOXDUR.**
# - > Bunlar **Bayes yanaşmasına** aiddir.
#
#
# ---
#
# #### 1️⃣ Maksimum Ehtimal Metodu (MLE) nə edir?
#
# MLE-nin məqsədi:
#
# > **Verilmiş müşahidələrə (data) görə parametri elə seç ki, data ən ehtimallı olsun.**
#
# Riyazi yazılışı:
#
# $$
# \hat{\theta}{MLE} = \arg\max\theta  p(y \mid \theta)
# $$
#
# Burada:
#
# * $y$ — müşahidə olunan data
# * $\theta$ — modelin parametri
# * $p(y \mid \theta)$ — **likelihood** (ehtimal funksiyası)
#
# #### 🔴 Diqqət
#
# - MLE yalnız **likelihood**-la işləyir.
# - **Prior və posterior ümumiyyətlə nəzərə alınmır.**
#
# ---
#
# #### 2️⃣ Prior nədir? (Bayes yanaşması)
#
# **Prior** — data görməzdən ƏVVƏL parametr haqqında inancımızdır:
#
# $$
# p(\theta)
# $$
#
# Məsələn:
#
# * “$\theta$ çox güman ki, 0-a yaxındır”
# * “$\theta$ müsbət olmalıdır”
#
# 👉 Bu **subyektiv və ya əvvəlki biliklərə əsaslanan** məlumatdır.
#
# 🔹 **MLE-də prior qəbul edilmir**
# - Yəni riyazi olaraq:
#
# $$
# p(\theta) = \text{const}
# $$
#
# (bütün $\theta$-lar eyni dərəcədə mümkündür)
#
# ---
#
# #### 3️⃣ Posterior nədir? (Bayes yanaşması)
#
# **Posterior** — data gördükdən SONRA parametr haqqında bilikdir:
#
# $$
# p(\theta \mid y)
# $$
#
# Bayes düsturu:
#
# $$
# p(\theta \mid y) = \frac{p(y \mid \theta) \ p(\theta)}{p(y)}
# $$
#
# Burada:
#
# * Likelihood: $p(y \mid \theta)$ - $ \ $ **$\theta$-nı elə seçirik ki, verilmiş $y$ üçün ehtimal maksimum olsun**
# * Prior: $p(\theta)$
# * Posterior: $p(\theta \mid y)$
#
# ---
#
# #### 4️⃣ MLE ilə Bayes əlaqəsi (ən vacib məqam)
#
# Əgər **prior sabitdirsə** (informativ deyil):
#
# $$
# p(\theta) = \text{const}
# $$
#
# onda:
#
# $$
# \arg\max_\theta p(\theta \mid y)
# =
# \arg\max_\theta p(y \mid \theta)
# $$
#
#
#
# ➡️ **MLE = MAP estimator** (xüsusi halda)
#
# Yəni:
#
# * MLE — prior **yoxmuş kimi davranır**
# * Bayes — prioru **açıq şəkildə** istifadə edir
#
# ---
#
# #### 5️⃣ Qısa müqayisə cədvəli
#
# | **Anlayış**                     | **MLE**          | **Bayes**    |
# | --------------------------- | ------------ | -------- |
# | **Prior $p(\theta)$**           | **❌ yoxdur**     | **✅ var**    |
# | **Posterior $p(\theta\mid y)$** | **❌ yoxdur**     | **✅ var**    |
# | **Likelihood**                 | **✅ var**        | **✅ var**    |
# | **Nəticə**                     | **Nöqtə qiymət** |**Paylanma** |
#
# ---
#
# ## 6️⃣ Intuitiv misal 🎯
#
# Tutaq ki, sikkə atırsan.
#
# * **MLE deyir:**
#   - “Yalnız atış nəticələrinə baxıram.”
#
# * **Bayes deyir:**
#   - “Əvvəlcə sikkə barədə fikrim var (prior), sonra nəticələrlə yeniləyirəm (posterior).”
#
# ---
#
# #### 🔑 Yekun cümlə
#
# - > **Maksimum Ehtimal Metodu prior və posterior istifadə ETMİR**
# - > **Prior və posterior Bayes statistikaya aiddir.**

# %% [markdown]
# ### Praktik Fəlsəfəsi

# %% [markdown]
# #### 1️⃣ Problem nədir?
#
# Bizim **naməlum parametrimiz** var:
#
# **θ (teta)** — məsələn:
#
# * orta qiymət
# * ehtimal
# * model parametri
#
# Və **müşahidələrimiz** var:
#
# **y = (y₁, y₂, …, yₙ)** — real datadan gələn ədədlər.
#
# 👉 Sual: **θ neçədir?**
#
# ---
#
# #### 2️⃣ Maksimum Ehtimal Metodu (MLE) – fəlsəfəsi
#
# #### Əsas fikir:
#
# > “Hansı θ bu müşahidə etdiyim datanı **ən mümkün** edir?”
#
# #### Riyazi yazılış:
#
# $$
# \hat{\theta}_{\text{MLE}}
# =
# \arg\max_{\theta} \, p(y \mid \theta)
# $$
#
#
# #### Vacib məqam ⚠️
#
# Burada:
#
# * **θ təsadüfi deyil**
# * **θ sabit, amma naməlumdur**
# * ehtimal **yalnız dataya aiddir**
#
# Yəni MLE deyir:
#
# > “Mən θ haqqında heç nə bilmirəm. Sadəcə elə θ tapım ki, bu data onunla ən yaxşı izah olunsun.”
#
# 📌 **Keçmiş bilik YOXDUR**
#
# ---
#
# #### 3️⃣ Bayes nəzəriyyəsi – böyük fərq burada başlayır
#
# Bayes deyir:
#
# > “θ haqqında datadan ƏVVƏL də fikrim ola bilər”
#
# Bu fikrə deyilir:
#
# ### 🔹 Prior
#
# $$
# p(\theta)
# $$
#
# — datanı görməzdən əvvəl θ haqqında inancımız.
#
# ---
#
# #### 4️⃣ Bayes düsturu (ürək nöqtəsi ❤️)
#
# $$
# p(\theta \mid y)
# =
# \frac{p(y \mid \theta)\, p(\theta)}{p(y)}
# $$
#
#
# Burada:
#
# * **p(θ | y)** → posterior (datanı görəndən SONRA θ-ya inam)
# * **p(y | θ)** → likelihood (MLE-də istifadə etdiyimiz) - $ \ $ **$\theta$-nı elə seçirik ki, verilmiş $y$ üçün ehtimal maksimum olsun**
# * **p(θ)** → prior
# * **p(y)** → sadəcə normallaşdırma sabiti
#
# ---
#
# #### 5️⃣ MAP – MLE ilə Bayesin qovuşduğu yer
#
# Bayes çərçivəsində konkret bir qiymət tapmaq istəsək:
#
# $$
# \hat{\theta}_{\text{MAP}}
# =
# \arg\max_{\theta} \, p(\theta \mid y)
# $$
#
#
# Bayes düsturunu yerinə qoyaq:
#
# $$
# \hat{\theta}_{\text{MAP}}
# =
# \arg\max_{\theta}
# \Big(
# p(y \mid \theta)\, p(\theta)
# \Big)
# $$
#
#
# 📌 **p(y)** yoxdur, çünki θ-dan asılı deyil.
#
# ---
#
# #### 6️⃣ ƏN VACİB NÖQTƏ (burada qaranlıq qalır adətən)
#
# #### Əgər prior “neytral”dirsə (uniform prior):
#
# $$
# p(\theta) = sabit
# $$
#
# onda:
#
# $$
# \hat{\theta}_{\text{MAP}}
# =
# \arg\max_{\theta} p(y \mid \theta)
# =
# \hat{\theta}_{\text{MLE}}
# $$
#
#
# 🔥 **Nəticə:**
#
# > **MLE — Bayes-in xüsusi halıdır**
#
# Bu cümləni başa düşdünsə, mövzu oturdu.
#
# ---
#
# #### 7️⃣ Sadə real misal (tam otursun deyə)
#
# #### Zər misalı 🎲
#
# * 10 dəfə atdın
# * 7 dəfə “6” gəldi
#
# #### MLE deyir:
#
# $$
# \hat{p} = \frac{7}{10}
# $$
#
# Çünki bu ehtimal datanı ən yaxşı izah edir.
#
# ---
#
# #### Bayes deyir:
#
# > “Mən əvvəldən zərin ədalətli olduğuna inanıram”
#
# Prior:
# $$
# p \sim Beta(10,10)
# $$
#
# Posterior:
# $$
# p \mid y \sim Beta(17,13)
# $$
#
# 📌 Burada:
#
# * az data → prior təsir edir
# * çox data → likelihood qalib gəlir
#
#
#
# #### p nədir burada?
#
# **p** — bir hadisənin ehtimalıdır.
#
# Məsələn:
#
# * zər atırıq
# * “6” gəlmə ehtimalı = **p**
# * p-ni **bilmirik**
#
#
# ####  Beta(α, β) nə deməkdir? (ən vacib hissə)
#
# **Beta paylanması** ehtimal üçündür, çünki:
#
# $$
# 0 \le p \le 1
# $$
#
# #### Beta(α, β)-nin mənası:
#
# * **α − 1** → “uğur” sayı kimi düşün
# * **β − 1** → “uğursuzluq” sayı kimi düşün
#
# 📌 Bu **real müşahidə deyil**, **inancdır**.
#
#
#
# #### Prior: Beta(10, 10) nə deyir?
#
# $$
# p \sim Beta(10,10)
# $$
#
# Bu o deməkdir ki:
#
# * əvvəlcədən elə düşünürük ki:
#
#   * 9 dəfə “6” gəlib
#   * 9 dəfə “6” gəlməyib
#
# 👉 Yəni:
#
# * p ≈ 0.5
# * amma **tam əmin deyilik**
#
# 📊 Orta qiymət:
# $$
# E[p] = \frac{10}{10+10} = 0.5
# $$
#
#
#
# #### 4️⃣ İndi DATA gəlir (çox vacib)
#
# 10 dəfə zər atdıq:
#
# * 7 dəfə “6” gəldi → uğur
# * 3 dəfə gəlmədi → uğursuzluq
#
# Bu artıq **likelihood**-dur.
#
#
#
# ####  Bayes burada nə edir? (sehrli hissə ✨)
#
# #### Qayda:
#
# $$
# \text{Beta}(\alpha,\beta)
# \;+\;
# (k \text{ uğur},\, n-k \text{ uğursuzluq})
# \;\longrightarrow\;
# \text{Beta}(\alpha + k,\; \beta + n - k)
# $$
#
#
#
# #### Rəqəmləri yerinə qoyaq
#
# Prior:
#
# * α = 10
# * β = 10
#
# Data:
#
# * k = 7 (uğur)
# * n−k = 3 (uğursuzluq)
#
# Posterior:
# $$
# p \mid y \sim \text{Beta}(10+7,\, 10+3)
# =
# \text{Beta}(17,13)
# $$
#
#
# 🔥 BU QƏDƏR SADƏDİR.
#
#
# ####  Nəticə nə deyir?
#
# #### Posterior orta qiymət:
#
# $$
# E[p \mid y] = \frac{17}{17+13} = \frac{17}{30} \approx 0.567
# $$
#
# 📌 Diqqət et:
#
# * MLE deyərdi: **7/10 = 0.7**
# * Bayes deyir: **0.567**
#
# Niyə?
#
# > Çünki **əvvəl p ≈ 0.5** deyə düşünürdük və data azdır.
#
#
#
# #### Intuisiya ilə yadında saxla 🧠
#
# * **Prior = əvvəlki təcrübə**
# * **Likelihood = yeni data**
# * **Posterior = ikisinin balansı**
#
# 📌 Çox data gəlsəydi:
#
# * 700 uğur, 300 uğursuzluq
# * posterior ≈ 0.7 olardı
# * priorun təsiri itib gedərdi
#
#
#
# #### 1 cümləlik yaddaş kartı 🧾
#
# > **Beta prior + Binomial data = Beta posterior**
#
# ---
#
# #### 8️⃣ Yekun – 1 cümləlik yadda saxla
#
# > **MLE**: “Data nə deyir?”
# >
# > **Bayes**: “Data + əvvəlki bilik nə deyir?”
